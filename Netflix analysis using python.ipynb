# %%
import pandas as pd

# %%
data= pd.read_csv(r'C:\Users\lenovo\Downloads\New folder\Youtube_project_shan_singh\netflix-rotten-tomatoes-metacritic-imdb.csv')

# %%
data
# Out:
#                                            Title  \
# 0                               Lets Fight Ghost
# 1                            HOW TO BUILD A GIRL
# 2                                     Centigrade
# 3                                          ANNE+
# 4                                          Moxie
# ...                                          ...
# 15475                     K-POP Extreme Survival
# 15476            DreamWorks Shreks Swamp Stories
# 15477  DreamWorks Happy Holidays from Madagascar
# 15478                DreamWorks Holiday Classics
# 15479   DreamWorks Kung Fu Panda Awesome Secrets
#
#                                         Genre  \
# 0      Crime, Drama, Fantasy, Horror, Romance
# 1                                      Comedy
# 2                             Drama, Thriller
# 3                                       Drama
# 4                     Animation, Short, Drama
# ...                                       ...
# ...

# %% [markdown]
# ## HEAD() = to show top 5 data of the dataset

# %%
data.head()
# Out:
#                  Title                                   Genre  \
# 0     Lets Fight Ghost  Crime, Drama, Fantasy, Horror, Romance
# 1  HOW TO BUILD A GIRL                                  Comedy
# 2           Centigrade                         Drama, Thriller
# 3                ANNE+                                   Drama
# 4                Moxie                 Animation, Short, Drama
#
#                                                 Tags         Languages  \
# 0  Comedy Programmes,Romantic TV Comedies,Horror ...  Swedish, Spanish
# 1       Dramas,Comedies,Films Based on Books,British           English
# 2                                          Thrillers           English
# 3        TV Dramas,Romantic TV Dramas,Dutch TV Shows           Turkish
# 4  Social Issue Dramas,Teen Movies,Dramas,Comedie...           English
#
#   Series or Movie  Hidden Gem Score  \
# 0          Series               4.3
# 1           Movie               7.0
# 2           Movie               6.4
# ...

# %% [markdown]
# ## TAIL() to show last 5 data from the dataset

# %%
data.tail()
# Out:
#                                            Title  \
# 15475                     K-POP Extreme Survival
# 15476            DreamWorks Shreks Swamp Stories
# 15477  DreamWorks Happy Holidays from Madagascar
# 15478                DreamWorks Holiday Classics
# 15479   DreamWorks Kung Fu Panda Awesome Secrets
#
#                                    Genre  \
# 15475                                NaN
# 15476                                NaN
# 15477          Animation, Comedy, Family
# 15478          Animation, Comedy, Family
# 15479  Animation, Action, Comedy, Family
#
#                                                     Tags Languages  \
# 15475  TV Dramas,TV Programmes,TV Comedies,Romantic T...       NaN
# 15476  Animal Tales,Family Comedies,Family Adventures...       NaN
# 15477  TV Comedies,Kids TV,Animal Tales,TV Cartoons,T...   English
# 15478  TV Comedies,Kids TV,TV Cartoons,TV Programmes,...   English
# 15479  TV Comedies,Kids TV,Animal Tales,TV Cartoons,T...   English
#
# ...

# %% [markdown]
# ## shape == to  show the number of the row and the numbers of column in the data

# %%
data.shape
# Out:
# (15480, 29)

# %% [markdown]
# ## 4. SIZE to show the totel number of element(values) in the data sets

# %%
data.size
# Out:
# 448920

# %% [markdown]
# ## columns = to show each column name

# %%
data.columns
# Out:
# Index(['Title', 'Genre', 'Tags', 'Languages', 'Series or Movie',
#        'Hidden Gem Score', 'Country Availability', 'Runtime', 'Director',
#        'Writer', 'Actors', 'View Rating', 'IMDb Score',
#        'Rotten Tomatoes Score', 'Metacritic Score', 'Awards Received',
#        'Awards Nominated For', 'Boxoffice', 'Release Date',
#        'Netflix Release Date', 'Production House', 'Netflix Link', 'IMDb Link',
#        'Summary', 'IMDb Votes', 'Image', 'Poster', 'TMDb Trailer',
#        'Trailer Site'],
#       dtype='object')

# %%
list(data.columns)
# Out:
# ['Title',
#  'Genre',
#  'Tags',
#  'Languages',
#  'Series or Movie',
#  'Hidden Gem Score',
#  'Country Availability',
#  'Runtime',
#  'Director',
#  'Writer',
#  'Actors',
#  'View Rating',
#  'IMDb Score',
#  'Rotten Tomatoes Score',
#  'Metacritic Score',
#  'Awards Received',
#  'Awards Nominated For',
#  'Boxoffice',
#  'Release Date',
#  'Netflix Release Date',
#  'Production House',
#  'Netflix Link',
#  'IMDb Link',
#  'Summary',
#  'IMDb Votes',
#  'Image',
#  'Poster',
#  'TMDb Trailer',
#  'Trailer Site']

# %% [markdown]
# ## dtypes = to show the data type of the each columns

# %%
data.dtypes
# Out:
# Title                     object
# Genre                     object
# Tags                      object
# Languages                 object
# Series or Movie           object
# Hidden Gem Score         float64
# Country Availability      object
# Runtime                   object
# Director                  object
# Writer                    object
# Actors                    object
# View Rating               object
# IMDb Score               float64
# Rotten Tomatoes Score    float64
# Metacritic Score         float64
# Awards Received          float64
# Awards Nominated For     float64
# Boxoffice                 object
# Release Date              object
# Netflix Release Date      object
# Production House          object
# Netflix Link              object
# IMDb Link                 object
# Summary                   object
# IMDb Votes               float64
# Image                     object
# Poster                    object
# TMDb Trailer              object
# ...

# %% [markdown]
# ## info()= to show all the info about the index, columns, data type of each column in the dataset memory at once

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15480 entries, 0 to 15479
# Data columns (total 29 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Title                  15480 non-null  object
#  1   Genre                  13770 non-null  object
#  2   Tags                   15413 non-null  object
#  3   Languages              13545 non-null  object
#  4   Series or Movie        15480 non-null  object
#  5   Hidden Gem Score       13379 non-null  float64
#  6   Country Availability   15461 non-null  object
#  7   Runtime                15479 non-null  object
#  8   Director               10772 non-null  object
#  9   Writer                 11150 non-null  object
#  10  Actors                 13555 non-null  object
#  11  View Rating            8456 non-null   object
#  12  IMDb Score             13381 non-null  float64
#  13  Rotten Tomatoes Score  6382 non-null   float64
# ...

# %% [markdown]
# ## TASK = is there any duplicate value in the dataset? if yes, remove them

# %% [markdown]
# ## duplicate()

# %%
data.shape
# Out:
# (15480, 29)

# %%
data[data.duplicated()]  # as we can see there are no duplicate values to remove
# Out:
# Empty DataFrame
# Columns: [Title, Genre, Tags, Languages, Series or Movie, Hidden Gem Score, Country Availability, Runtime, Director, Writer, Actors, View Rating, IMDb Score, Rotten Tomatoes Score, Metacritic Score, Awards Received, Awards Nominated For, Boxoffice, Release Date, Netflix Release Date, Production House, Netflix Link, IMDb Link, Summary, IMDb Votes, Image, Poster, TMDb Trailer, Trailer Site]
# Index: []
#
# [0 rows x 29 columns]

# %% [markdown]
# ## if there were any duplicate value the we would used the following to remove them

# %%
data.drop_duplicates(inplace = True)    # using this function the duplicate values are deleted (inplace command is used to remove the dupliacte value permanently fromm data set)

# %% [markdown]
# ## Task-  Check for null values in any column.. Show with heat maps

# %% [markdown]
# # isnull()

# %%
data.head()
# Out:
#                  Title                                   Genre  \
# 0     Lets Fight Ghost  Crime, Drama, Fantasy, Horror, Romance
# 1  HOW TO BUILD A GIRL                                  Comedy
# 2           Centigrade                         Drama, Thriller
# 3                ANNE+                                   Drama
# 4                Moxie                 Animation, Short, Drama
#
#                                                 Tags         Languages  \
# 0  Comedy Programmes,Romantic TV Comedies,Horror ...  Swedish, Spanish
# 1       Dramas,Comedies,Films Based on Books,British           English
# 2                                          Thrillers           English
# 3        TV Dramas,Romantic TV Dramas,Dutch TV Shows           Turkish
# 4  Social Issue Dramas,Teen Movies,Dramas,Comedie...           English
#
#   Series or Movie  Hidden Gem Score  \
# 0          Series               4.3
# 1           Movie               7.0
# 2           Movie               6.4
# ...

# %%
data.isnull() #null values in boolean form.
# Out:
#        Title  Genre   Tags  Languages  Series or Movie  Hidden Gem Score  \
# 0      False  False  False      False            False             False
# 1      False  False  False      False            False             False
# 2      False  False  False      False            False             False
# 3      False  False  False      False            False             False
# 4      False  False  False      False            False             False
# ...      ...    ...    ...        ...              ...               ...
# 15475  False   True  False       True            False              True
# 15476  False   True  False       True            False              True
# 15477  False  False  False      False            False             False
# 15478  False  False  False      False            False             False
# 15479  False  False  False      False            False             False
#
#        Country Availability  Runtime  Director  Writer  ...  \
# ...

# %%
data.isnull().sum()  #to show the count of null values in each column
# Out:
# Title                        0
# Genre                     1710
# Tags                        67
# Languages                 1935
# Series or Movie              0
# Hidden Gem Score          2101
# Country Availability        19
# Runtime                      1
# Director                  4708
# Writer                    4330
# Actors                    1925
# View Rating               7024
# IMDb Score                2099
# Rotten Tomatoes Score     9098
# Metacritic Score         11144
# Awards Received           9405
# Awards Nominated For      7819
# Boxoffice                11473
# Release Date              2107
# Netflix Release Date         0
# Production House         10331
# Netflix Link                 0
# IMDb Link                 2303
# Summary                      9
# IMDb Votes                2101
# Image                        0
# Poster                    3638
# TMDb Trailer              8286
# Trailer Site              8286
# dtype: int64

# %% [markdown]
# # for heat map we need SEABORN library

# %%
import seaborn as sns

# %%
sns.heatmap(data.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# # For 'Stranger Things' check its show id and directors name

# %% [markdown]
# ### isin()

# %%
data.head()
# Out:
#                  Title                                   Genre  \
# 0     Lets Fight Ghost  Crime, Drama, Fantasy, Horror, Romance
# 1  HOW TO BUILD A GIRL                                  Comedy
# 2           Centigrade                         Drama, Thriller
# 3                ANNE+                                   Drama
# 4                Moxie                 Animation, Short, Drama
#
#                                                 Tags         Languages  \
# 0  Comedy Programmes,Romantic TV Comedies,Horror ...  Swedish, Spanish
# 1       Dramas,Comedies,Films Based on Books,British           English
# 2                                          Thrillers           English
# 3        TV Dramas,Romantic TV Dramas,Dutch TV Shows           Turkish
# 4  Social Issue Dramas,Teen Movies,Dramas,Comedie...           English
#
#   Series or Movie  Hidden Gem Score  \
# 0          Series               4.3
# 1           Movie               7.0
# 2           Movie               6.4
# ...

# %%
data['Title'].isin(['House of cards'])
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 15475    False
# 15476    False
# 15477    False
# 15478    False
# 15479    False
# Name: Title, Length: 15480, dtype: bool

# %%
data[data['Title'].isin(['Stranger Things'])]      #to show all item in perticular column
# Out:
#                  Title                                              Genre  \
# 11183  Stranger Things  Drama, Fantasy, Horror, Mystery, Sci-Fi, Thriller
#
#                                                     Tags         Languages  \
# 11183  TV Thrillers,TV Sci-Fi & Fantasy,TV Programmes...  English, Russian
#
#       Series or Movie  Hidden Gem Score  \
# 11183          Series               4.3
#
#                                     Country Availability       Runtime  \
# 11183  Sweden,Belgium,France,Netherlands,Spain,German...  < 30 minutes
#
#       Director                    Writer  ... Netflix Release Date  \
# 11183      NaN  Ross Duffer, Matt Duffer  ...           2016-07-15
#
#       Production House                            Netflix Link  \
# 11183              NaN  https://www.netflix.com/watch/80057281
#
#                                   IMDb Link  \
# 11183  https://www.imdb.com/title/tt4574334
#
# ...

# %% [markdown]
# ### str.contains()

# %%
data[data['Title'].str.contains('Stranger Things')]     # to show all values with the string in any column
# Out:
#                         Title  \
# 11183         Stranger Things
# 12846  Beyond Stranger Things
#
#                                                    Genre  \
# 11183  Drama, Fantasy, Horror, Mystery, Sci-Fi, Thriller
# 12846                             Documentary, Talk-Show
#
#                                                     Tags         Languages  \
# 11183  TV Thrillers,TV Sci-Fi & Fantasy,TV Programmes...  English, Russian
# 12846  TV Programmes,TV Sci-Fi & Fantasy,Teen TV Prog...           English
#
#       Series or Movie  Hidden Gem Score  \
# 11183          Series               4.3
# 12846          Series               7.9
#
#                                     Country Availability       Runtime  \
# 11183  Sweden,Belgium,France,Netherlands,Spain,German...  < 30 minutes
# 12846  United States,Brazil,Spain,United Kingdom,Aust...  < 30 minutes
#
#       Director                    Writer  ... Netflix Release Date  \
# ...

# %% [markdown]
# ## In which year highest movie or tv show released? With bar graph

# %%
#first check if the data type you wish to get the result from is in right format like,
# in this case we wish to get the year details which is of time type. so check if the column data type is in time format then,
#proceed with it otherwise create a dummy column and assign your required coloum to that dummy column with the data type you wish to work with

# %% [markdown]
# ### dtypes

# %%
data.dtypes
# Out:
# Title                     object
# Genre                     object
# Tags                      object
# Languages                 object
# Series or Movie           object
# Hidden Gem Score         float64
# Country Availability      object
# Runtime                   object
# Director                  object
# Writer                    object
# Actors                    object
# View Rating               object
# IMDb Score               float64
# Rotten Tomatoes Score    float64
# Metacritic Score         float64
# Awards Received          float64
# Awards Nominated For     float64
# Boxoffice                 object
# Release Date              object
# Netflix Release Date      object
# Production House          object
# Netflix Link              object
# IMDb Link                 object
# Summary                   object
# IMDb Votes               float64
# Image                     object
# Poster                    object
# TMDb Trailer              object
# ...

# %%
# in this case our release date data type is in object. so we need date time format so we will use following command

# %% [markdown]
# ### to_datetime

# %%
data['Date_New'] = pd.to_datetime(data['Release Date'])

# %%
data.dtypes
# Out:
# Title                            object
# Genre                            object
# Tags                             object
# Languages                        object
# Series or Movie                  object
# Hidden Gem Score                float64
# Country Availability             object
# Runtime                          object
# Director                         object
# Writer                           object
# Actors                           object
# View Rating                      object
# IMDb Score                      float64
# Rotten Tomatoes Score           float64
# Metacritic Score                float64
# Awards Received                 float64
# Awards Nominated For            float64
# Boxoffice                        object
# Release Date                     object
# Netflix Release Date             object
# Production House                 object
# Netflix Link                     object
# IMDb Link                        object
# ...

# %% [markdown]
# ### dt.year.value_counts()

# %%
data['Date_New'].dt.year.value_counts()  #it counts all occurance of indiviual years in date column
# Out:
# 2018.0    1495
# 2017.0    1408
# 2019.0    1330
# 2016.0    1097
# 2015.0     882
#           ...
# 1943.0       1
# 1938.0       1
# 1913.0       1
# 1946.0       1
# 1936.0       1
# Name: Date_New, Length: 105, dtype: int64

# %%
list(data.columns)
# Out:
# ['Title',
#  'Genre',
#  'Tags',
#  'Languages',
#  'Series or Movie',
#  'Hidden Gem Score',
#  'Country Availability',
#  'Runtime',
#  'Director',
#  'Writer',
#  'Actors',
#  'View Rating',
#  'IMDb Score',
#  'Rotten Tomatoes Score',
#  'Metacritic Score',
#  'Awards Received',
#  'Awards Nominated For',
#  'Boxoffice',
#  'Release Date',
#  'Netflix Release Date',
#  'Production House',
#  'Netflix Link',
#  'IMDb Link',
#  'Summary',
#  'IMDb Votes',
#  'Image',
#  'Poster',
#  'TMDb Trailer',
#  'Trailer Site',
#  'Date_New']

# %% [markdown]
# ### bar graph

# %%
data['Date_New'].dt.year.value_counts().plot(kind= 'area')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## How many movie and tv shows are in the dataset? Show with the bar graph

# %% [markdown]
# ### groupby()

# %%
 data.head(2)             ## to group all the unique items in the data set and show thier count
# Out:
#                  Title                                   Genre  \
# 0     Lets Fight Ghost  Crime, Drama, Fantasy, Horror, Romance
# 1  HOW TO BUILD A GIRL                                  Comedy
#
#                                                 Tags         Languages  \
# 0  Comedy Programmes,Romantic TV Comedies,Horror ...  Swedish, Spanish
# 1       Dramas,Comedies,Films Based on Books,British           English
#
#   Series or Movie  Hidden Gem Score Country Availability       Runtime  \
# 0          Series               4.3             Thailand  < 30 minutes
# 1           Movie               7.0               Canada      1-2 hour
#
#           Director                 Writer  ...  \
# 0  Tomas Alfredson  John Ajvide Lindqvist  ...
# 1    Coky Giedroyc          Caitlin Moran  ...
#
#                          Production House  \
# 0               Canal+, Sandrew Metronome
# 1  Film 4, Monumental Pictures, Lionsgate
#
#                              Netflix Link  \
# ...

# %%
data.rename(columns={"Series or Movie": "Category"}, inplace=True)

# %%
data.groupby('Category').Category.count()
# Out:
# Category
# Movie     11697
# Series     3783
# Name: Category, dtype: int64

# %% [markdown]
# ### countplot()

# %%
sns.countplot(data['Category'])     #to show the count of all the unique values in columns in form of bar graph
# Out:
# C:\Users\lenovo\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Category', ylabel='count'>

# %% [markdown]
# ## Show all the movies released in year 2000

# %% [markdown]
# ### create new column

# %%
data.head(2)
# Out:
#                  Title                                   Genre  \
# 0     Lets Fight Ghost  Crime, Drama, Fantasy, Horror, Romance
# 1  HOW TO BUILD A GIRL                                  Comedy
#
#                                                 Tags         Languages  \
# 0  Comedy Programmes,Romantic TV Comedies,Horror ...  Swedish, Spanish
# 1       Dramas,Comedies,Films Based on Books,British           English
#
#   Category  Hidden Gem Score Country Availability       Runtime  \
# 0   Series               4.3             Thailand  < 30 minutes
# 1    Movie               7.0               Canada      1-2 hour
#
#           Director                 Writer  ...  \
# 0  Tomas Alfredson  John Ajvide Lindqvist  ...
# 1    Coky Giedroyc          Caitlin Moran  ...
#
#                          Production House  \
# 0               Canal+, Sandrew Metronome
# 1  Film 4, Monumental Pictures, Lionsgate
#
#                              Netflix Link  \
# ...

# %%
data['Date_year']= data['Date_New'].dt.year

# %% [markdown]
# ### filtering

# %%
data[(data['Category']== 'Movie') & (data['Date_year']== 2000)]
# Out:
#                          Title                              Genre  \
# 483                  Butterfly                              Drama
# 510                  Love Song                     Drama, Romance
# 553                Big Brother              Game-Show, Reality-TV
# 771           The Grooms Price                            Mystery
# 851    Godzilla vs. Megaguirus             Action, Horror, Sci-Fi
# ...                        ...                                ...
# 15184             Center Stage              Drama, Music, Romance
# 15224          Erin Brockovich                   Biography, Drama
# 15263              Bring It On             Comedy, Romance, Sport
# 15318          American Psycho               Comedy, Crime, Drama
# 15396              The 6th Day  Action, Mystery, Sci-Fi, Thriller
#
#                                                     Tags  \
# 483                      Korean Movies,Documentary Films
# ...

# %%
data[(data['Category']== 'Movie') & (data['Date_year']== 2022)]
# Out:
#                           Title Genre  \
# 1332  Blumhouses Fantasy Island   NaN
#
#                                                    Tags Languages Category  \
# 1332  Sci-Fi & Fantasy,Horror Movies,Fantasy Movies,...       NaN    Movie
#
#       Hidden Gem Score                               Country Availability  \
# 1332               NaN  South Korea,Hong Kong,Thailand,Netherlands,Sin...
#
#        Runtime Director Writer  ...                            Netflix Link  \
# 1332  1-2 hour      NaN    NaN  ...  https://www.netflix.com/watch/81189449
#
#                                   IMDb Link  \
# 1332  https://www.imdb.com/title/tt10954690
#
#                                                 Summary  IMDb Votes  \
# 1332  When the host of a mysterious island resort pr...         NaN
#
#                                                   Image  Poster  TMDb Trailer  \
# 1332  https://occ-0-1007-1360.1.nflxso.net/dnm/api/v...     NaN           NaN
#
# ...

# %% [markdown]
# ## Show  only title of tv shows that released in india only

# %%
data.head(5)
# Out:
#                  Title                                   Genre  \
# 0     Lets Fight Ghost  Crime, Drama, Fantasy, Horror, Romance
# 1  HOW TO BUILD A GIRL                                  Comedy
# 2           Centigrade                         Drama, Thriller
# 3                ANNE+                                   Drama
# 4                Moxie                 Animation, Short, Drama
#
#                                                 Tags         Languages  \
# 0  Comedy Programmes,Romantic TV Comedies,Horror ...  Swedish, Spanish
# 1       Dramas,Comedies,Films Based on Books,British           English
# 2                                          Thrillers           English
# 3        TV Dramas,Romantic TV Dramas,Dutch TV Shows           Turkish
# 4  Social Issue Dramas,Teen Movies,Dramas,Comedie...           English
#
#   Category  Hidden Gem Score  \
# 0   Series               4.3
# 1    Movie               7.0
# 2    Movie               6.4
# 3   Series               7.7
# ...

# %%
data.rename(columns={'Country Availability': "Country"}, inplace=True)

# %%
data[(data['Category']== 'Series') & (data['Country']=='India')]
# Out:
#                              Title                      Genre  \
# 239                         Blippi                     Family
# 1200         Mias Magic Playground               Short, Drama
# 1201                  Supa Strikas   Animation, Family, Sport
# 1887                The Luminaries  Adventure, Drama, Mystery
# 2108      The Salisbury Poisonings   Drama, History, Thriller
# 2501                 Uma and Devan                  Animation
# 5207                 Beecham House                      Drama
# 7409              Go Astro Boy Go!                        NaN
# 8757   Eena Meena Deeka: हिंदी में                  Animation
# 11671                     The O.C.                      Adult
# 15253                     Beyblade              Family, Sport
# 15446           Two and a Half Men            Comedy, Romance
#
#                                                     Tags  \
# 239                      Education for Kids,Kids&#39; TV
# ...

# %%
data[(data['Category']== 'Series') & (data['Country']=='India')]['Title']
# Out:
# 239                           Blippi
# 1200           Mias Magic Playground
# 1201                    Supa Strikas
# 1887                  The Luminaries
# 2108        The Salisbury Poisonings
# 2501                   Uma and Devan
# 5207                   Beecham House
# 7409                Go Astro Boy Go!
# 8757     Eena Meena Deeka: हिंदी में
# 11671                       The O.C.
# 15253                       Beyblade
# 15446             Two and a Half Men
# Name: Title, dtype: object

# %% [markdown]
# ## Show top 10 directors who gave highest number of tv show and  movies to netflix

# %% [markdown]
# ### value_counts()

# %%
data.head(2)
# Out:
#                  Title                                   Genre  \
# 0     Lets Fight Ghost  Crime, Drama, Fantasy, Horror, Romance
# 1  HOW TO BUILD A GIRL                                  Comedy
#
#                                                 Tags         Languages  \
# 0  Comedy Programmes,Romantic TV Comedies,Horror ...  Swedish, Spanish
# 1       Dramas,Comedies,Films Based on Books,British           English
#
#   Category  Hidden Gem Score   Country       Runtime         Director  \
# 0   Series               4.3  Thailand  < 30 minutes  Tomas Alfredson
# 1    Movie               7.0    Canada      1-2 hour    Coky Giedroyc
#
#                   Writer  ...                            Netflix Link  \
# 0  John Ajvide Lindqvist  ...  https://www.netflix.com/watch/81415947
# 1          Caitlin Moran  ...  https://www.netflix.com/watch/81041267
#
#                               IMDb Link  \
# 0  https://www.imdb.com/title/tt1139797
# 1  https://www.imdb.com/title/tt4193072
#
# ...

# %%
data['Director'].value_counts().head(10)
# Out:
# Steven Spielberg          28
# Raúl Campos, Jan Suter    19
# Woody Allen               18
# Johnnie To                18
# Ridley Scott              17
# Marcus Raboy              17
# Steven Soderbergh         16
# Jing Wong                 16
# Clint Eastwood            16
# Pedro Almodóvar           16
# Name: Director, dtype: int64

# %% [markdown]
# ## show all the records where category is movies and  genre is comedy or country is Canada

# %% [markdown]
# ### Filtering ( using 'And' and 'OR' operator)

# %%
data.head()
# Out:
#                  Title                                   Genre  \
# 0     Lets Fight Ghost  Crime, Drama, Fantasy, Horror, Romance
# 1  HOW TO BUILD A GIRL                                  Comedy
# 2           Centigrade                         Drama, Thriller
# 3                ANNE+                                   Drama
# 4                Moxie                 Animation, Short, Drama
#
#                                                 Tags         Languages  \
# 0  Comedy Programmes,Romantic TV Comedies,Horror ...  Swedish, Spanish
# 1       Dramas,Comedies,Films Based on Books,British           English
# 2                                          Thrillers           English
# 3        TV Dramas,Romantic TV Dramas,Dutch TV Shows           Turkish
# 4  Social Issue Dramas,Teen Movies,Dramas,Comedie...           English
#
#   Category  Hidden Gem Score  \
# 0   Series               4.3
# 1    Movie               7.0
# 2    Movie               6.4
# 3   Series               7.7
# ...

# %%
data[(data['Genre']== 'Comedy') & (data['Category']=='Movie') | (data['Country']== 'Canada')]
# Out:
#                                                    Title  \
# 1                                    HOW TO BUILD A GIRL
# 2                                             Centigrade
# 9                                             Snowroller
# 25                                           The Coroner
# 28                                            The Closet
# ...                                                  ...
# 15442  Teenage Mutant Ninja Turtles II: The Secret of...
# 15450                 Chelsea Peretti: One of the Greats
# 15458                                           Year One
# 15461                                  One for the Money
# 15473                        Daniel Arends: Blessuretijd
#
#                                            Genre  \
# 1                                         Comedy
# 2                                Drama, Thriller
# 9                                         Comedy
# 25                                  Crime, Drama
# ...

# %% [markdown]
# ## how many movies  are from tag THRILLERs

# %%
data.head()
# Out:
#                  Title                                   Genre  \
# 0     Lets Fight Ghost  Crime, Drama, Fantasy, Horror, Romance
# 1  HOW TO BUILD A GIRL                                  Comedy
# 2           Centigrade                         Drama, Thriller
# 3                ANNE+                                   Drama
# 4                Moxie                 Animation, Short, Drama
#
#                                                 Tags         Languages  \
# 0  Comedy Programmes,Romantic TV Comedies,Horror ...  Swedish, Spanish
# 1       Dramas,Comedies,Films Based on Books,British           English
# 2                                          Thrillers           English
# 3        TV Dramas,Romantic TV Dramas,Dutch TV Shows           Turkish
# 4  Social Issue Dramas,Teen Movies,Dramas,Comedie...           English
#
#   Category  Hidden Gem Score  \
# 0   Series               4.3
# 1    Movie               7.0
# 2    Movie               6.4
# 3   Series               7.7
# ...

# %% [markdown]
# ### filtering

# %%
data[(data['Tags']== 'Thrillers') &(data['Category']=='Movie')]
# Out:
#                          Title                                       Genre  \
# 2                   Centigrade                             Drama, Thriller
# 142                   Unhinged                            Action, Thriller
# 2459         The Model Murders                                         NaN
# 2460           Lineage of Lies                                         NaN
# 2803              Fatal Deceit                                         NaN
# 3108           Girls Night Out                               Comedy, Drama
# 3109             Early Release                      Short, Drama, Thriller
# 4085     Pretty Little Stalker                    Drama, Mystery, Thriller
# 4809             Deadly Shores                                    Thriller
# 5575               Killer Cove                                    Thriller
# 6025               The Student                                    Thriller
# ...

# %% [markdown]
# ### str.contains()

# %%
data[data['Tags'].str.contains('Thrillers')]     # error came coz this str.contains() func cannot work on null values to solve this we will do the following
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7456/519523030.py in <module>
# ----> 1 data[data['Tags'].str.contains('Thrillers')]     # error came coz this str.contains() func cannot work on null values to solve this we will do the following
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3446
#    3447         # Do we have a (boolean) 1d indexer?
# -> 3448         if com.is_bool_indexer(key):
#    3449             return self._getitem_bool_array(key)
#    3450
#
# ~\anaconda3\lib\site-packages\pandas\core\common.py in is_bool_indexer(key)
#     137                     # Don't raise on e.g. ["A", "B", np.nan], see
#     138                     #  test_loc_getitem_list_of_labels_categoricalindex_with_na
# --> 139                     raise ValueError(na_msg)
#     140                 return False
# ...

# %% [markdown]
# ## Create new data frame

# %%
# data_new = data.dropna() it drops  rows that containing all or any missing values

# %%
data_new = data.dropna()

# %%
data_new.head(2)  # now all the null values have been removed from the new data frame. and now use the str.contains() again
# Out:
#     Title                               Genre  \
# 15  Joker              Crime, Drama, Thriller
# 16      I  Action, Adventure, Fantasy, Sci-Fi
#
#                                                  Tags          Languages  \
# 15  Dark Comedies,Crime Comedies,Dramas,Comedies,C...            English
# 16                              Dramas,Swedish Movies  English, Sanskrit
#
#    Category  Hidden Gem Score  \
# 15    Movie               3.5
# 16    Movie               2.8
#
#                                               Country   Runtime  \
# 15  Lithuania,Poland,France,Italy,Spain,Greece,Bel...  1-2 hour
# 16  Lithuania,Poland,France,Italy,Spain,Greece,Cze...  1-2 hour
#
#          Director                                             Writer  ...  \
# 15  Todd Phillips  Scott Silver, Jerry Robinson, Todd Phillips, B...  ...
# 16   George Lucas                                       George Lucas  ...
#
#                               Netflix Link  \
# ...

# %%
data_new[data_new['Tags'].str.contains('Thrillers')]
# Out:
#                                    Title  \
# 60                       Ordinary People
# 96                 The Girl on the Train
# 251            The House That Jack Built
# 349    Marlina the Murderer in Four Acts
# 372                             Infamous
# ...                                  ...
# 15394                              Seven
# 15427                            Blade 2
# 15434                        Bad Boys II
# 15449                               2012
# 15453                       3:10 to Yuma
#
#                                            Genre  \
# 60                                         Drama
# 96               Crime, Drama, Mystery, Thriller
# 251               Crime, Drama, Horror, Thriller
# 349                     Drama, Thriller, Western
# 372                      Biography, Crime, Drama
# ...                                          ...
# 15394            Crime, Drama, Mystery, Thriller
# 15427  Action, Fantasy, Horror, Sci-Fi, Thriller
# ...

# %% [markdown]
# ## What are the different rating given by netflix?

# %% [markdown]
# ### nunique()

# %%
data.rename(columns={'Hidden Gem Score':'Rating'}, inplace= True)

# %%
data['Rating'].nunique()
# Out:
# 93

# %% [markdown]
# ### unique()

# %%
data['Rating'].unique()
# Out:
# array([4.3, 7. , 6.4, 7.7, 8.1, 8.6, 8.7, 6.9, 8.3, 5.3, 7.5, 2. , 7.8,
#        8.8, 3.5, 2.8, 4.4, 7.9, 7.6, 8.5, 3.9, 3.8, 6.7, 7.1, 8.4, 8.2,
#        6.2, 9.3, 7.3, 4.2, 4.1, 8. , 6. , 7.4, 8.9, 3.1, 3.6, 6.3, 5.4,
#        5.9, 4. , 7.2, 2.6, 9. , 2.3, 9.2, 6.6, 3.4, 5.7, 6.5, 5. , 2.5,
#        2.4, 4.7, 6.8, 3.7, 6.1, 3. , 9.7, nan, 3.2, 9.1, 2.9, 9.8, 5.1,
#        5.8, 2.2, 5.6, 1.9, 4.9, 2.7, 1.7, 3.3, 1.4, 1.5, 5.2, 5.5, 4.5,
#        1.6, 1.2, 2.1, 4.6, 4.8, 9.4, 9.6, 9.5, 1.3, 1.8, 1. , 0.9, 0.8,
#        1.1, 0.6, 0.7])

# %% [markdown]
# ## how many movies got 6.6 rating in Canada

# %%
data.head(2)
# Out:
#                  Title                                   Genre  \
# 0     Lets Fight Ghost  Crime, Drama, Fantasy, Horror, Romance
# 1  HOW TO BUILD A GIRL                                  Comedy
#
#                                                 Tags         Languages  \
# 0  Comedy Programmes,Romantic TV Comedies,Horror ...  Swedish, Spanish
# 1       Dramas,Comedies,Films Based on Books,British           English
#
#   Category  Rating   Country       Runtime         Director  \
# 0   Series     4.3  Thailand  < 30 minutes  Tomas Alfredson
# 1    Movie     7.0    Canada      1-2 hour    Coky Giedroyc
#
#                   Writer  ...                            Netflix Link  \
# 0  John Ajvide Lindqvist  ...  https://www.netflix.com/watch/81415947
# 1          Caitlin Moran  ...  https://www.netflix.com/watch/81041267
#
#                               IMDb Link  \
# 0  https://www.imdb.com/title/tt1139797
# 1  https://www.imdb.com/title/tt4193072
#
# ...

# %%
data[(data['Category']=='Movie') & (data['Rating']==6.6)&(data['Country']=='Canada')].shape
# Out:
# (3, 31)

# %% [markdown]
# ## How many movies/Show got 7 rating after 2018

# %%
data[(data['Rating']==7)&(data['Date_year']>2018)].shape
# Out:
# (47, 31)

# %% [markdown]
# ##  Which individual country has the Highest No. of TV Shows ?

# %%
data.head()
# Out:
#                  Title                                   Genre  \
# 0     Lets Fight Ghost  Crime, Drama, Fantasy, Horror, Romance
# 1  HOW TO BUILD A GIRL                                  Comedy
# 2           Centigrade                         Drama, Thriller
# 3                ANNE+                                   Drama
# 4                Moxie                 Animation, Short, Drama
#
#                                                 Tags         Languages  \
# 0  Comedy Programmes,Romantic TV Comedies,Horror ...  Swedish, Spanish
# 1       Dramas,Comedies,Films Based on Books,British           English
# 2                                          Thrillers           English
# 3        TV Dramas,Romantic TV Dramas,Dutch TV Shows           Turkish
# 4  Social Issue Dramas,Teen Movies,Dramas,Comedie...           English
#
#   Category  Rating                                            Country  \
# 0   Series     4.3                                           Thailand
# ...

# %%
data_Onlytv = data[data['Category']=='Series']

# %%
data_Onlytv.head()      #made a new data frame having only tv series
# Out:
#                           Title                                   Genre  \
# 0              Lets Fight Ghost  Crime, Drama, Fantasy, Horror, Romance
# 3                         ANNE+                                   Drama
# 6                  Gleboka woda                                   Drama
# 7                      Instynkt                                   Crime
# 23  Girls und Panzer das Finale               Animation, Action, Comedy
#
#                                                  Tags         Languages  \
# 0   Comedy Programmes,Romantic TV Comedies,Horror ...  Swedish, Spanish
# 3         TV Dramas,Romantic TV Dramas,Dutch TV Shows           Turkish
# 6    TV Dramas,Polish TV Shows,Social Issue TV Dramas            Polish
# 7           TV Dramas,Crime TV Dramas,Polish TV Shows            Polish
# 23  Drama Anime,Action & Adventure,Action Anime,An...          Japanese
#
#    Category  Rating              Country       Runtime           Director  \
# ...

# %%
data_Onlytv.Country.value_counts()
# Out:
# Japan                                                                                                                                                                                                                                                                                                                                377
# United Kingdom                                                                                                                                                                                                                                                                                                                       111
# Switzerland,Germany                                                                                                                                                                                                                                                                                                                   99
# ...

# %% [markdown]
# ## How can we sort the dataset by Year ?

# %%
data.head(2)
# Out:
#                  Title                                   Genre  \
# 0     Lets Fight Ghost  Crime, Drama, Fantasy, Horror, Romance
# 1  HOW TO BUILD A GIRL                                  Comedy
#
#                                                 Tags         Languages  \
# 0  Comedy Programmes,Romantic TV Comedies,Horror ...  Swedish, Spanish
# 1       Dramas,Comedies,Films Based on Books,British           English
#
#   Category  Rating   Country       Runtime         Director  \
# 0   Series     4.3  Thailand  < 30 minutes  Tomas Alfredson
# 1    Movie     7.0    Canada      1-2 hour    Coky Giedroyc
#
#                   Writer  ...                            Netflix Link  \
# 0  John Ajvide Lindqvist  ...  https://www.netflix.com/watch/81415947
# 1          Caitlin Moran  ...  https://www.netflix.com/watch/81041267
#
#                               IMDb Link  \
# 0  https://www.imdb.com/title/tt1139797
# 1  https://www.imdb.com/title/tt4193072
#
# ...

# %%
data.sort_values(by='Date_year')
# Out:
#                                            Title  \
# 3249                        The Way of the World
# 426                                 Il Traditore
# 1516                          The Price of Peace
# 211                                Ingeborg Holm
# 1329                         Into the Wilderness
# ...                                          ...
# 15475                     K-POP Extreme Survival
# 15476            DreamWorks Shreks Swamp Stories
# 15477  DreamWorks Happy Holidays from Madagascar
# 15478                DreamWorks Holiday Classics
# 15479   DreamWorks Kung Fu Panda Awesome Secrets
#
#                                    Genre  \
# 3249                        Drama, Short
# 426                                Short
# 1516                        Short, Drama
# 211                                Drama
# 1329                        Short, Drama
# ...                                  ...
# 15475                                NaN
# ...

# %%
data.sort_values(by='Date_year', ascending = False).head(2)
# Out:
#                           Title                            Genre  \
# 1332  Blumhouses Fantasy Island                              NaN
# 167                    Capitani  Crime, Drama, Mystery, Thriller
#
#                                                    Tags      Languages  \
# 1332  Sci-Fi & Fantasy,Horror Movies,Fantasy Movies,...            NaN
# 167                           TV Dramas,Crime TV Dramas  Luxembourgish
#
#      Category  Rating                                            Country  \
# 1332    Movie     NaN  South Korea,Hong Kong,Thailand,Netherlands,Sin...
# 167    Series     8.4  Lithuania,Poland,Iceland,Italy,Spain,Greece,Cz...
#
#            Runtime Director Writer  ...  \
# 1332      1-2 hour      NaN    NaN  ...
# 167   < 30 minutes      NaN    NaN  ...
#
#                                 Netflix Link  \
# 1332  https://www.netflix.com/watch/81189449
# 167   https://www.netflix.com/watch/81277858
#
#                                   IMDb Link  \
# ...

# %%
data.head()
# Out:
#                  Title                                   Genre  \
# 0     Lets Fight Ghost  Crime, Drama, Fantasy, Horror, Romance
# 1  HOW TO BUILD A GIRL                                  Comedy
# 2           Centigrade                         Drama, Thriller
# 3                ANNE+                                   Drama
# 4                Moxie                 Animation, Short, Drama
#
#                                                 Tags         Languages  \
# 0  Comedy Programmes,Romantic TV Comedies,Horror ...  Swedish, Spanish
# 1       Dramas,Comedies,Films Based on Books,British           English
# 2                                          Thrillers           English
# 3        TV Dramas,Romantic TV Dramas,Dutch TV Shows           Turkish
# 4  Social Issue Dramas,Teen Movies,Dramas,Comedie...           English
#
#   Category  Rating                                            Country  \
# 0   Series     4.3                                           Thailand
# ...

# %% [markdown]
# ## Find all the instances where:
# ### Category is 'Movie' and Genre is 'Drama' OR Category is 'Series' & Genre is 'Animation'.

# %%
data[((data['Category']=='Movie')& (data['Genre']=='Drama'))| ((data['Category']=='Series')&(data['Genre']==''))]
# Out:
#                                                Title  Genre  \
# 8                                      Only a Mother  Drama
# 12                        The Simple Minded Murderer  Drama
# 22                                              1939  Drama
# 31                                            Repast  Drama
# 33                   When a Woman Ascends the Stairs  Drama
# ...                                              ...    ...
# 15128         Divine Secrets of the Ya-Ya Sisterhood  Drama
# 15163                                  Gods Not Dead  Drama
# 15257  Precious: Based on the Novel Push by Sapphire  Drama
# 15330                             American History X  Drama
# 15395                                   Seven Pounds  Drama
#
#                                                     Tags         Languages  \
# 8      Social Issue Dramas,Dramas,Movies Based on Boo...           Swedish
# 12     Social Issue Dramas,Dramas,Movies Based on Boo...  Scanian, Swedish
# ...
